# %% [markdown]
# # An easy guide to "not throwing your expensive computer out the window because you can't run a Python neuroimaging tool"

# %% [markdown]
# ## Personal background
# My name is Claudéric, I am graduate student at Université de Montréal, I'm doing a master in psychology at the moment. I am somewhat experienced with programming and computer science in general. My field of interest is signal processing in neuroimage/psychophysiological signal. My master project is on the evaluation of different program and pipeline for preprocessing electrodermal activity (EDA) signal.

# %% [markdown]
# ## Project background
# <img align="right" width="500" height="400" src="https://c.tenor.com/9ItR8nSuxE0AAAAd/thumbs-up-computer.gif">Working with computer in context of neuroimaging is awesome! There is a multitude of tools, programs, pipelines, etc. to analyse the so precious data we have collected.

# %% [markdown]
# ## Project background
# <img align="right" width="600" height="400" src="https://c.tenor.com/hKTCoKfeJGQAAAAd/hate-this.gif">But somtimes, working with computer might be more a challenge than anything else. I mean we all have been there at least once...

# %% [markdown]
# ## Project background
# But there is no need for all this frustration!
# Of all the awesome tools availble, there are some that exist to simplify things.

# %% [markdown]
# ## Project background
# One of the best way to easily run code for your analysis is to use:
#
# Scripting 		       	 | Packaging		        	|  Containerize
# :-----------------------:|:----------------------------:|:----------------------------:
# <img width=300px height=300px src="https://cdn-icons-png.flaticon.com/512/2572/2572499.png"/>  |  <img width=300px height=300px src="https://cdn-icons-png.flaticon.com/512/814/814989.png"/>  |  <img width=300px height=300px src="https://cdn-icons-png.flaticon.com/512/5969/5969028.png"/>

# %% [markdown]
# ## Project background
# In 2012, Gronenschil et al. have found difference in volume of brain area using two versions of the same software on different computer as well as on two versions of the same OS. This means that I could run some analysis with software X and another researcher runs the same analysis with the exact same software X but with a more up to date OS than me and we'll get different results.

# %% [markdown]
# Gronenschild, E. H. B. M., Habets, P., Jacobs, H. I. L., Mengelers, R., Rozendaal, N., van Os, J., & Marcelis, M. (2012). The Effects of FreeSurfer Version, Workstation Type, and Macintosh Operating System Version on Anatomical Volume and Cortical Thickness Measurements. PLoS ONE, 7(6), e38234. https://doi.org/10.1371/journal.pone.0038234

# %% [markdown]
# ## Goals/objectives
# I mainly want to familirize myself with scripting, packaging, containerizing and using HPC so that I will be able to redo what I did with the project for future projects.

# %% [markdown]
# ## Goals/objectives
# Precisely here what I want to do :
# - Scripting the seed to voxel correlation code
# - Do same thing but for the machine learning code
# - Using `git` and GitHub to version control everything I do and make it publicly avaible
# - Familiarize myself with the use of HPC (Calcul Canada, Brainchack cloud (maybe))
# - Learn to use Singularity to use Docker container or file within HPC
# - Containerize everything
# - Make a useful and easy to follow guide for inexperience user to install and run everything

# %% [markdown]
# maybe talk about the black box user experience vs the hole package deal

# %% [markdown]
# ## Tools
# <img src="https://laptopmetlinux.nl/wp-content/uploads/Clevo-NL51RU-Linux-laptop-kopen-1-700x700.png"/>

# %% [markdown]
# ## Tools
# Really, I will use :
# - [Python]("https://www.python.org/")
# - `git`
# - [GitHub]("https://github.com/")
# - Scripting and packaging for Python
# - [Bash]("https://www.gnu.org/software/bash/")
# - [Calcul Canada]("https://alliancecan.ca/en") or [Brainhack Cloud]("https://brainhack.org/brainhack_cloud/")

# %% [markdown]
# ## Data
# I don't really have data, because I will work more on code than on data.
# <img align="right" width=400px height=600px  src="https://c.tenor.com/9ud1r4sc-QQAAAAC/confused-john-travolta.gif">

# %% [markdown]
# ## Data
# But, I will still use some data to test everything and to be sure everything is working correctly.

# %% [markdown]
# ## Deliverables
# By the end of the project I would want to produce :
# - the script, package and the container for the seed to voxel correlation code
# - if the star align properly, I will do the same for the machine learning code as well
# - a tutorial/guide (document or a video, I didn't decide yet) to explain to someone with zero background in computer science how to install everything and run the code

# %% [markdown]
# ## Conclusion
# My project is more focus on making code (here the seed to voxel correlation code) more accessible, easily installable and more stable accross OS, librairy version, etc.
#
# Thank you for your attention!
